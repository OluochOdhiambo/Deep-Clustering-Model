# %%
from keras.datasets import mnist
import numpy as np
np.random.seed(10)

# %%
from time import time
import numpy as np
import keras.backend as K
from keras.engine.topology import Layer, InputSpec
from keras.layers import Dense, Input
from keras.models import Model
from keras.optimizers import SGD
from keras import callbacks
from keras.initializers import VarianceScaling
from sklearn.cluster import KMeans

# %%
def autoencoder(dims, act='relu', init='glorot_uniform'):
    """
    Fully connected auto-encoder model, symmetric.
    Arguments:
        dims: list of number of units in each layer of encoder. dims[0] is input dim, dims[-1] is units in hidden layer.
            The decoder is symmetric with encoder. So number of layers of the auto-encoder is 2*len(dims)-1
        act: activation, not applied to Input, Hidden and Output layers
    return:
        (ae_model, encoder_model), Model of autoencoder and model of encoder
    """
    n_stacks = len(dims) - 1
    # input
    input_img = Input(shape=(dims[0],), name='input')
    x = input_img
    # internal layers in encoder
    for i in range(n_stacks-1):
        x = Dense(dims[i + 1], activation=act, kernel_initializer=init, name='encoder_%d' % i)(x)

    # hidden layer
    encoded = Dense(dims[-1], kernel_initializer=init, name='encoder_%d' % (n_stacks - 1))(x)  # hidden layer, features are extracted from here

    x = encoded
    # internal layers in decoder
    for i in range(n_stacks-1, 0, -1):
        x = Dense(dims[i], activation=act, kernel_initializer=init, name='decoder_%d' % i)(x)

    # output
    x = Dense(dims[0], kernel_initializer=init, name='decoder_0')(x)
    decoded = x
    return Model(inputs=input_img, outputs=decoded, name='AE'), Model(inputs=input_img, outputs=encoded, name='encoder')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x = np.concatenate((x_train, x_test))
y = np.concatenate((y_train, y_test))
x = x.reshape((x.shape[0], -1))
x = np.divide(x, 255.)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
n_clusters = len(np.unique(y))
x.shape
# Out:
# (70000, 784)

# %% [markdown]
# ## Define Accuracy Metric

# %%
import numpy as np
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score

nmi = normalized_mutual_info_score
ari = adjusted_rand_score


def acc(y_true, y_pred):
    """
    Calculate clustering accuracy. Require scikit-learn installed
    # Arguments
        y: true labels, numpy.array with shape `(n_samples,)`
        y_pred: predicted labels, numpy.array with shape `(n_samples,)`
    # Return
        accuracy, in [0,1]
    """
    y_true = y_true.astype(np.int64)
    assert y_pred.size == y_true.size
    D = max(y_pred.max(), y_true.max()) + 1
    w = np.zeros((D, D), dtype=np.int64)
    for i in range(y_pred.size):
        w[y_pred[i], y_true[i]] += 1
    from sklearn.utils.linear_assignment_ import linear_assignment
    ind = linear_assignment(w.max() - w)
    return sum([w[i, j] for i, j in ind]) * 1.0 / y_pred.size

# %%
kmeans = KMeans(n_clusters=n_clusters, n_init=20, n_jobs=4)
y_pred_kmeans = kmeans.fit_predict(x)
acc(y, y_pred_kmeans)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:22: FutureWarning: The linear_assignment_ module is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# 0.5322857142857143

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
dims = [x.shape[-1], 500, 500, 2000, 10]
init = VarianceScaling(scale=1. / 3., mode='fan_in',
                           distribution='uniform')
pretrain_optimizer = SGD(lr=1, momentum=0.9)
pretrain_epochs = 300
batch_size = 256
save_dir = '/content/drive/MyDrive/models'

# %%
autoencoder, encoder = autoencoder(dims, init=init)

# %%
from keras.utils import plot_model
plot_model(autoencoder, to_file='autoencoder.png', show_shapes=True)
from IPython.display import Image
Image(filename='autoencoder.png')

# %%
from keras.utils import plot_model
plot_model(encoder, to_file='encoder.png', show_shapes=True)
from IPython.display import Image
Image(filename='encoder.png')

# %%
autoencoder.compile(optimizer=pretrain_optimizer, loss='mse')
autoencoder.fit(x, x, batch_size=batch_size, epochs=pretrain_epochs) #, callbacks=cb)
autoencoder.save_weights(save_dir + '/ae_weights.h5')
# Out:
# Epoch 1/300
# 274/274 [==============================] - 3s 4ms/step - loss: 0.0749
# Epoch 2/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0508
# Epoch 3/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0344
# Epoch 4/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0281
# Epoch 5/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0249
# Epoch 6/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0231
# Epoch 7/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0218
# Epoch 8/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0207
# Epoch 9/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0199
# Epoch 10/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0192
# Epoch 11/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0187
# Epoch 12/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0182
# Epoch 13/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0178
# Epoch 14/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0174
# Epoch 15/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0171
# Epoch 16/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0168
# Epoch 17/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0165
# Epoch 18/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0163
# Epoch 19/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0160
# Epoch 20/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0159
# Epoch 21/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0156
# Epoch 22/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0154
# Epoch 23/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0153
# Epoch 24/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0151
# Epoch 25/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0150
# Epoch 26/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0148
# Epoch 27/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0146
# Epoch 28/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0146
# Epoch 29/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0144
# Epoch 30/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0143
# Epoch 31/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0142
# Epoch 32/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0141
# Epoch 33/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0139
# Epoch 34/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0138
# Epoch 35/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0137
# Epoch 36/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0137
# Epoch 37/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0135
# Epoch 38/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0135
# Epoch 39/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0134
# Epoch 40/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0133
# Epoch 41/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0132
# Epoch 42/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0132
# Epoch 43/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0131
# Epoch 44/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0130
# Epoch 45/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0129
# Epoch 46/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0129
# Epoch 47/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0128
# Epoch 48/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0128
# Epoch 49/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0127
# Epoch 50/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0126
# Epoch 51/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0125
# Epoch 52/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0125
# Epoch 53/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0125
# Epoch 54/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0124
# Epoch 55/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0124
# Epoch 56/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0123
# Epoch 57/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0123
# Epoch 58/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0121
# Epoch 59/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0121
# Epoch 60/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0121
# Epoch 61/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0120
# Epoch 62/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0120
# Epoch 63/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0119
# Epoch 64/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0119
# Epoch 65/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0118
# Epoch 66/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0118
# Epoch 67/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0118
# Epoch 68/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0117
# Epoch 69/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0117
# Epoch 70/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0116
# Epoch 71/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0116
# Epoch 72/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0116
# Epoch 73/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0115
# Epoch 74/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0115
# Epoch 75/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0115
# Epoch 76/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0114
# Epoch 77/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0114
# Epoch 78/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0114
# Epoch 79/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0113
# Epoch 80/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0112
# Epoch 81/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0112
# Epoch 82/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0112
# Epoch 83/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0112
# Epoch 84/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0111
# Epoch 85/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0111
# Epoch 86/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0111
# Epoch 87/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0110
# Epoch 88/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0110
# Epoch 89/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0110
# Epoch 90/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0109
# Epoch 91/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0109
# Epoch 92/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0109
# Epoch 93/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0108
# Epoch 94/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0108
# Epoch 95/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0108
# Epoch 96/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0108
# Epoch 97/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0107
# Epoch 98/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0107
# Epoch 99/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0107
# Epoch 100/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0107
# Epoch 101/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0107
# Epoch 102/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0106
# Epoch 103/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0106
# Epoch 104/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0105
# Epoch 105/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0105
# Epoch 106/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0105
# Epoch 107/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0105
# Epoch 108/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0104
# Epoch 109/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0105
# Epoch 110/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0104
# Epoch 111/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0104
# Epoch 112/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0104
# Epoch 113/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0104
# Epoch 114/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0103
# Epoch 115/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0103
# Epoch 116/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0103
# Epoch 117/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0103
# Epoch 118/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0102
# Epoch 119/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0102
# Epoch 120/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0102
# Epoch 121/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0102
# Epoch 122/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0102
# Epoch 123/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0101
# Epoch 124/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0101
# Epoch 125/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0101
# Epoch 126/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0101
# Epoch 127/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0101
# Epoch 128/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0100
# Epoch 129/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0100
# Epoch 130/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0100
# Epoch 131/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0100
# Epoch 132/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0100
# Epoch 133/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0100
# Epoch 134/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0099
# Epoch 135/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0099
# Epoch 136/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0099
# Epoch 137/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0099
# Epoch 138/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 139/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0099
# Epoch 140/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 141/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 142/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 143/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 144/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 145/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 146/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 147/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0097
# Epoch 148/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0097
# Epoch 149/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0097
# Epoch 150/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0097
# Epoch 151/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0097
# Epoch 152/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0096
# Epoch 153/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0096
# Epoch 154/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0096
# Epoch 155/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0096
# Epoch 156/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0096
# Epoch 157/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0096
# Epoch 158/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0096
# Epoch 159/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0096
# Epoch 160/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0095
# Epoch 161/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0095
# Epoch 162/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0095
# Epoch 163/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0095
# Epoch 164/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0095
# Epoch 165/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0095
# Epoch 166/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0095
# Epoch 167/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0095
# Epoch 168/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0094
# Epoch 169/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0094
# Epoch 170/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0094
# Epoch 171/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0094
# Epoch 172/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0094
# Epoch 173/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0093
# Epoch 174/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0094
# Epoch 175/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0094
# Epoch 176/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0093
# Epoch 177/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0093
# Epoch 178/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0093
# Epoch 179/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0093
# Epoch 180/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0093
# Epoch 181/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0093
# Epoch 182/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0093
# Epoch 183/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 184/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 185/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 186/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 187/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 188/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 189/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 190/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 191/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 192/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 193/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 194/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0091
# Epoch 195/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0091
# Epoch 196/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0091
# Epoch 197/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0091
# Epoch 198/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0091
# Epoch 199/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 200/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0091
# Epoch 201/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0091
# Epoch 202/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 203/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 204/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 205/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 206/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 207/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 208/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 209/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 210/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 211/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 212/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 213/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 214/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 215/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 216/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 217/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 218/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 219/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 220/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 221/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 222/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 223/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 224/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 225/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 226/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 227/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 228/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 229/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 230/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 231/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 232/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 233/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 234/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 235/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 236/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 237/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 238/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 239/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 240/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 241/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 242/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 243/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 244/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 245/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 246/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 247/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 248/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 249/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 250/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 251/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 252/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 253/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 254/300
# 274/274 [==============================] - 1s 5ms/step - loss: 0.0086
# Epoch 255/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 256/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 257/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 258/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 259/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 260/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 261/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 262/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 263/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 264/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 265/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 266/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 267/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 268/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 269/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 270/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 271/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 272/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 273/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 274/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 275/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 276/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 277/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 278/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 279/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 280/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 281/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 282/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 283/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 284/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 285/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 286/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 287/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 288/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 289/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 290/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 291/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 292/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 293/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 294/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 295/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 296/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 297/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 298/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 299/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 300/300
# 274/274 [==============================] - 1s 4ms/step - loss: 0.0083

# %%
autoencoder.save_weights(save_dir + '/ae_weights.h5')

# %%
autoencoder.load_weights(save_dir + '/ae_weights.h5')

# %%
class ClusteringLayer(Layer):
    """
    Clustering layer converts input sample (feature) to soft label, i.e. a vector that represents the probability of the
    sample belonging to each cluster. The probability is calculated with student's t-distribution.

    # Example
    ```
        model.add(ClusteringLayer(n_clusters=10))
    ```
    # Arguments
        n_clusters: number of clusters.
        weights: list of Numpy array with shape `(n_clusters, n_features)` witch represents the initial cluster centers.
        alpha: degrees of freedom parameter in Student's t-distribution. Default to 1.0.
    # Input shape
        2D tensor with shape: `(n_samples, n_features)`.
    # Output shape
        2D tensor with shape: `(n_samples, n_clusters)`.
    """

    def __init__(self, n_clusters, weights=None, alpha=1.0, **kwargs):
        if 'input_shape' not in kwargs and 'input_dim' in kwargs:
            kwargs['input_shape'] = (kwargs.pop('input_dim'),)
        super(ClusteringLayer, self).__init__(**kwargs)
        self.n_clusters = n_clusters
        self.alpha = alpha
        self.initial_weights = weights
        self.input_spec = InputSpec(ndim=2)

    def build(self, input_shape):
        assert len(input_shape) == 2
        input_dim = input_shape[1]
        self.input_spec = InputSpec(dtype=K.floatx(), shape=(None, input_dim))
        self.clusters = self.add_weight(name='clusters', shape=(self.n_clusters, input_dim), initializer='glorot_uniform')
        if self.initial_weights is not None:
            self.set_weights(self.initial_weights)
            del self.initial_weights
        self.built = True

    def call(self, inputs, **kwargs):
        """ student t-distribution, as same as used in t-SNE algorithm.
         Measure the similarity between embedded point z_i and centroid µ_j.
                 q_ij = 1/(1+dist(x_i, µ_j)^2), then normalize it.
                 q_ij can be interpreted as the probability of assigning sample i to cluster j.
                 (i.e., a soft assignment)
        Arguments:
            inputs: the variable containing data, shape=(n_samples, n_features)
        Return:
            q: student's t-distribution, or soft labels for each sample. shape=(n_samples, n_clusters)
        """
        q = 1.0 / (1.0 + (K.sum(K.square(K.expand_dims(inputs, axis=1) - self.clusters), axis=2) / self.alpha))
        q **= (self.alpha + 1.0) / 2.0
        q = K.transpose(K.transpose(q) / K.sum(q, axis=1)) # Make sure each sample's 10 values add up to 1.
        return q

    def compute_output_shape(self, input_shape):
        assert input_shape and len(input_shape) == 2
        return input_shape[0], self.n_clusters

    def get_config(self):
        config = {'n_clusters': self.n_clusters}
        base_config = super(ClusteringLayer, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
clustering_layer = ClusteringLayer(n_clusters, name='clustering')(encoder.output)
model = Model(inputs=encoder.input, outputs=clustering_layer)

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)
from IPython.display import Image
Image(filename='model.png')

# %%
model.compile(optimizer=SGD(0.01, 0.9), loss='kld')

# %%
kmeans = KMeans(n_clusters=n_clusters, n_init=20)
y_pred = kmeans.fit_predict(encoder.predict(x))

# %%
y_pred_last = np.copy(y_pred)

# %%
model.get_layer(name='clustering').set_weights([kmeans.cluster_centers_])

# %%
# computing an auxiliary target distribution
def target_distribution(q):
    weight = q ** 2 / q.sum(0)
    return (weight.T / weight.sum(1)).T

# %%
loss = 0
index = 0
maxiter = 8000
update_interval = 140
index_array = np.arange(x.shape[0])

# %%
tol = 0.001 # tolerance threshold to stop training

# %%
for ite in range(int(maxiter)):
    if ite % update_interval == 0:
        q = model.predict(x, verbose=0)
        p = target_distribution(q)  # update the auxiliary target distribution p

        # evaluate the clustering performance
        y_pred = q.argmax(1)
        if y is not None:
            accuracy = round(acc(y, y_pred), 5)
            normalized = round(nmi(y, y_pred), 5)
            adjusted = round(ari(y, y_pred), 5)
            loss = round(loss, 5)
            print('Iter %d: acc = %.5f, nmi = %.5f, ari = %.5f' % (ite, accuracy, normalized, adjusted), ' ; loss=', loss)

        # check stop criterion - model convergence
        delta_label = np.sum(y_pred != y_pred_last).astype(np.float32) / y_pred.shape[0]
        y_pred_last = np.copy(y_pred)
        if ite > 0 and delta_label < tol:
            print('delta_label ', delta_label, '< tol ', tol)
            print('Reached tolerance threshold. Stopping training.')
            break
    idx = index_array[index * batch_size: min((index+1) * batch_size, x.shape[0])]
    loss = model.train_on_batch(x=x[idx], y=p[idx])
    index = index + 1 if (index + 1) * batch_size <= x.shape[0] else 0

model.save_weights(save_dir + '/DEC_model_final.h5')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 0: acc = 0.91761, nmi = 0.82601, ari = 0.82501  ; loss= 0
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 140: acc = 0.92137, nmi = 0.83083, ari = 0.83404  ; loss= 0.04651
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 280: acc = 0.93173, nmi = 0.84832, ari = 0.85546  ; loss= 0.15745
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 420: acc = 0.93879, nmi = 0.86045, ari = 0.87013  ; loss= 0.2066
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 560: acc = 0.94341, nmi = 0.86853, ari = 0.87966  ; loss= 0.21921
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 700: acc = 0.94663, nmi = 0.87407, ari = 0.88633  ; loss= 0.21478
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 840: acc = 0.94917, nmi = 0.87895, ari = 0.89155  ; loss= 0.21032
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 980: acc = 0.95073, nmi = 0.88178, ari = 0.89480  ; loss= 0.20485
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 1120: acc = 0.95234, nmi = 0.88474, ari = 0.89815  ; loss= 0.1979
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 1260: acc = 0.95387, nmi = 0.88748, ari = 0.90131  ; loss= 0.19759
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 1400: acc = 0.95470, nmi = 0.88896, ari = 0.90306  ; loss= 0.19076
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 1540: acc = 0.95549, nmi = 0.89058, ari = 0.90474  ; loss= 0.18217
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 1680: acc = 0.95591, nmi = 0.89139, ari = 0.90560  ; loss= 0.17605
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 1820: acc = 0.95680, nmi = 0.89328, ari = 0.90746  ; loss= 0.18236
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 1960: acc = 0.95709, nmi = 0.89379, ari = 0.90805  ; loss= 0.16966
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 2100: acc = 0.95750, nmi = 0.89470, ari = 0.90894  ; loss= 0.17049
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 2240: acc = 0.95789, nmi = 0.89555, ari = 0.90973  ; loss= 0.16826
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 2380: acc = 0.95807, nmi = 0.89609, ari = 0.91011  ; loss= 0.16294
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 2520: acc = 0.95839, nmi = 0.89667, ari = 0.91076  ; loss= 0.16109
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 2660: acc = 0.95841, nmi = 0.89701, ari = 0.91086  ; loss= 0.16674
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 2800: acc = 0.95869, nmi = 0.89732, ari = 0.91143  ; loss= 0.15758
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 2940: acc = 0.95874, nmi = 0.89750, ari = 0.91154  ; loss= 0.14724
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 3080: acc = 0.95881, nmi = 0.89782, ari = 0.91171  ; loss= 0.14951
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 3220: acc = 0.95874, nmi = 0.89767, ari = 0.91156  ; loss= 0.14191
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 3360: acc = 0.95906, nmi = 0.89829, ari = 0.91222  ; loss= 0.13982
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 3500: acc = 0.95899, nmi = 0.89842, ari = 0.91207  ; loss= 0.14074
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 3640: acc = 0.95917, nmi = 0.89879, ari = 0.91246  ; loss= 0.13592
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 3780: acc = 0.95917, nmi = 0.89896, ari = 0.91247  ; loss= 0.13135
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 3920: acc = 0.95903, nmi = 0.89873, ari = 0.91217  ; loss= 0.13501
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 4060: acc = 0.95913, nmi = 0.89898, ari = 0.91239  ; loss= 0.14045
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 4200: acc = 0.95896, nmi = 0.89862, ari = 0.91201  ; loss= 0.12815
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 4340: acc = 0.95900, nmi = 0.89892, ari = 0.91213  ; loss= 0.12492
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 4480: acc = 0.95893, nmi = 0.89866, ari = 0.91195  ; loss= 0.12666
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 4620: acc = 0.95900, nmi = 0.89891, ari = 0.91212  ; loss= 0.12935
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# Iter 4760: acc = 0.95903, nmi = 0.89879, ari = 0.91217  ; loss= 0.12706
# delta_label  0.0009428571428571429 < tol  0.001
# Reached tolerance threshold. Stopping training.

# %%
model.load_weights(save_dir + '/DEC_model_final.h5')

# %%
# Eval.
q = model.predict(x, verbose=0)
p = target_distribution(q)  # update the auxiliary target distribution p

# evaluate the clustering performance
y_pred = q.argmax(1)
if y is not None:
    accuracy1 = np.round(acc(y, y_pred), 5)
    normalized1 = np.round(nmi(y, y_pred), 5)
    adjusted1 = np.round(ari(y, y_pred), 5)
    loss = np.round(loss, 5)
    print('Acc = %.5f, nmi = %.5f, ari = %.5f' % (accuracy1, normalized1, adjusted1), ' ; loss=', loss)
# Out:
# Acc = 0.95903, nmi = 0.89879, ari = 0.91217  ; loss= 0.12706
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)

# %%
import seaborn as sns
import sklearn.metrics
import matplotlib.pyplot as plt
sns.set(font_scale=3)
confusion_matrix = sklearn.metrics.confusion_matrix(y, y_pred)

plt.figure(figsize=(16, 14))
sns.heatmap(confusion_matrix, annot=True, fmt="d", annot_kws={"size": 20});
plt.title("Confusion matrix", fontsize=30)
plt.ylabel('True label', fontsize=25)
plt.xlabel('Clustering label', fontsize=25)
plt.show()

# %%
y_pred
# Out:
# array([9, 2, 6, ..., 3, 9, 8])

# %%
x[0].shape
# Out:
# (784,)
